# %%
from kedro.context import load_context
context = load_context("e:\\jiang\\projects\\kedro-poc\\kedro-poc\\")

shuttles=context.catalog.load('shuttles')
shuttles.head(10)
# Out:
# 2019-10-14 20:57:54,701 - kedro.io.data_catalog - INFO - Loading data from `shuttles` (ExcelLocalDataSet)...
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
# 5  45163  Sao Tome and Principe      Type V5      Plasma  ThetaBase Services
# 6  64643          Faroe Islands      Type F5     Quantum  ThetaBase Services
# 7  23389             Micronesia      Type V5     Quantum  ThetaBase Services
# 8  39934                 Rwanda      Type V5     Quantum  ThetaBase Services
# 9  57063          Faroe Islands      Type F5      Plasma  ThetaBase Services
#
# ...
